# %% [markdown]
# ## Hurricane Analysis

# %%
# names of hurricanes
names = ['Cuba I', 'San Felipe II Okeechobee', 'Bahamas', 'Cuba II', 'CubaBrownsville', 'Tampico', 'Labor Day', 'New England', 'Carol', 'Janet', 'Carla', 'Hattie', 'Beulah', 'Camille', 'Edith', 'Anita', 'David', 'Allen', 'Gilbert', 'Hugo', 'Andrew', 'Mitch', 'Isabel', 'Ivan', 'Emily', 'Katrina', 'Rita', 'Wilma', 'Dean', 'Felix', 'Matthew', 'Irma', 'Maria', 'Michael']

# months of hurricanes
months = ['October', 'September', 'September', 'November', 'August', 'September', 'September', 'September', 'September', 'September', 'September', 'October', 'September', 'August', 'September', 'September', 'August', 'August', 'September', 'September', 'August', 'October', 'September', 'September', 'July', 'August', 'September', 'October', 'August', 'September', 'October', 'September', 'September', 'October']

# years of hurricanes
years = [1924, 1928, 1932, 1932, 1933, 1933, 1935, 1938, 1953, 1955, 1961, 1961, 1967, 1969, 1971, 1977, 1979, 1980, 1988, 1989, 1992, 1998, 2003, 2004, 2005, 2005, 2005, 2005, 2007, 2007, 2016, 2017, 2017, 2018]

# maximum sustained winds (mph) of hurricanes
max_sustained_winds = [165, 160, 160, 175, 160, 160, 185, 160, 160, 175, 175, 160, 160, 175, 160, 175, 175, 190, 185, 160, 175, 180, 165, 165, 160, 175, 180, 185, 175, 175, 165, 180, 175, 160]

# areas affected by each hurricane
areas_affected = [['Central America', 'Mexico', 'Cuba', 'Florida', 'The Bahamas'], ['Lesser Antilles', 'The Bahamas', 'United States East Coast', 'Atlantic Canada'], ['The Bahamas', 'Northeastern United States'], ['Lesser Antilles', 'Jamaica', 'Cayman Islands', 'Cuba', 'The Bahamas', 'Bermuda'], ['The Bahamas', 'Cuba', 'Florida', 'Texas', 'Tamaulipas'], ['Jamaica', 'Yucatn Peninsula'], ['The Bahamas', 'Florida', 'Georgia', 'The Carolinas', 'Virginia'], ['Southeastern United States', 'Northeastern United States', 'Southwestern Quebec'], ['Bermuda', 'New England', 'Atlantic Canada'], ['Lesser Antilles', 'Central America'], ['Texas', 'Louisiana', 'Midwestern United States'], ['Central America'], ['The Caribbean', 'Mexico', 'Texas'], ['Cuba', 'United States Gulf Coast'], ['The Caribbean', 'Central America', 'Mexico', 'United States Gulf Coast'], ['Mexico'], ['The Caribbean', 'United States East coast'], ['The Caribbean', 'Yucatn Peninsula', 'Mexico', 'South Texas'], ['Jamaica', 'Venezuela', 'Central America', 'Hispaniola', 'Mexico'], ['The Caribbean', 'United States East Coast'], ['The Bahamas', 'Florida', 'United States Gulf Coast'], ['Central America', 'Yucatn Peninsula', 'South Florida'], ['Greater Antilles', 'Bahamas', 'Eastern United States', 'Ontario'], ['The Caribbean', 'Venezuela', 'United States Gulf Coast'], ['Windward Islands', 'Jamaica', 'Mexico', 'Texas'], ['Bahamas', 'United States Gulf Coast'], ['Cuba', 'United States Gulf Coast'], ['Greater Antilles', 'Central America', 'Florida'], ['The Caribbean', 'Central America'], ['Nicaragua', 'Honduras'], ['Antilles', 'Venezuela', 'Colombia', 'United States East Coast', 'Atlantic Canada'], ['Cape Verde', 'The Caribbean', 'British Virgin Islands', 'U.S. Virgin Islands', 'Cuba', 'Florida'], ['Lesser Antilles', 'Virgin Islands', 'Puerto Rico', 'Dominican Republic', 'Turks and Caicos Islands'], ['Central America', 'United States Gulf Coast (especially Florida Panhandle)']]

# damages (USD($)) of hurricanes
damages = ['Damages not recorded', '100M', 'Damages not recorded', '40M', '27.9M', '5M', 'Damages not recorded', '306M', '2M', '65.8M', '326M', '60.3M', '208M', '1.42B', '25.4M', 'Damages not recorded', '1.54B', '1.24B', '7.1B', '10B', '26.5B', '6.2B', '5.37B', '23.3B', '1.01B', '125B', '12B', '29.4B', '1.76B', '720M', '15.1B', '64.8B', '91.6B', '25.1B']

# deaths for each hurricane
deaths = [90,4000,16,3103,179,184,408,682,5,1023,43,319,688,259,37,11,2068,269,318,107,65,19325,51,124,17,1836,125,87,45,133,603,138,3057,74]

# %% [markdown]
# #### Before start~

# %% [markdown]
# The data here is very messy. Put them into a DataFrame for better representation.  Save the DataFrame to `hurricane_df`.

# %%
### Your code here
import pandas as pd

hurricane_df = pd.DataFrame([
    names, months, years, max_sustained_winds, areas_affected, damages, deaths
], index=["name", "month", "year", "max_sustained_wind", "areas_affected", "damage", "death"]).T

# pd.DataFrame({
#     "name": names,
#     "month": months,
#     "year": years,
#     "max_sustained_wind": max_sustained_winds,
#     "areas_affected": areas_affected,
#     "damage": damages,
#     "death": deaths,
# })

hurricane_df
# Out:
#                         name      month  year max_sustained_wind  \
# 0                     Cuba I    October  1924                165
# 1   San Felipe II Okeechobee  September  1928                160
# 2                    Bahamas  September  1932                160
# 3                    Cuba II   November  1932                175
# 4            CubaBrownsville     August  1933                160
# 5                    Tampico  September  1933                160
# 6                  Labor Day  September  1935                185
# 7                New England  September  1938                160
# 8                      Carol  September  1953                160
# 9                      Janet  September  1955                175
# 10                     Carla  September  1961                175
# 11                    Hattie    October  1961                160
# 12                    Beulah  September  1967                160
# 13                   Camille     August  1969                175
# 14                     Edith  September  1971                160
# 15                     Anita  September  1977                175
# 16                     David     August  1979                175
# 17                     Allen     August  1980                190
# 18                   Gilbert  September  1988                185
# 19                      Hugo  September  1989                160
# 20                    Andrew     August  1992                175
# 21                     Mitch    October  1998                180
# 22                    Isabel  September  2003                165
# 23                      Ivan  September  2004                165
# 24                     Emily       July  2005                160
# 25                   Katrina     August  2005                175
# 26                      Rita  September  2005                180
# 27                     Wilma    October  2005                185
# 28                      Dean     August  2007                175
# 29                     Felix  September  2007                175
# 30                   Matthew    October  2016                165
# 31                      Irma  September  2017                180
# 32                     Maria  September  2017                175
# 33                   Michael    October  2018                160
#
#                                        areas_affected                damage  \
# 0   [Central America, Mexico, Cuba, Florida, The B...  Damages not recorded
# 1   [Lesser Antilles, The Bahamas, United States E...                  100M
# 2           [The Bahamas, Northeastern United States]  Damages not recorded
# 3   [Lesser Antilles, Jamaica, Cayman Islands, Cub...                   40M
# 4     [The Bahamas, Cuba, Florida, Texas, Tamaulipas]                 27.9M
# 5                         [Jamaica, Yucatn Peninsula]                    5M
# 6   [The Bahamas, Florida, Georgia, The Carolinas,...  Damages not recorded
# 7   [Southeastern United States, Northeastern Unit...                  306M
# 8             [Bermuda, New England, Atlantic Canada]                    2M
# 9                  [Lesser Antilles, Central America]                 65.8M
# 10       [Texas, Louisiana, Midwestern United States]                  326M
# 11                                  [Central America]                 60.3M
# 12                     [The Caribbean, Mexico, Texas]                  208M
# 13                   [Cuba, United States Gulf Coast]                 1.42B
# 14  [The Caribbean, Central America, Mexico, Unite...                 25.4M
# 15                                           [Mexico]  Damages not recorded
# 16          [The Caribbean, United States East coast]                 1.54B
# 17  [The Caribbean, Yucatn Peninsula, Mexico, Sout...                 1.24B
# 18  [Jamaica, Venezuela, Central America, Hispanio...                  7.1B
# 19          [The Caribbean, United States East Coast]                   10B
# 20   [The Bahamas, Florida, United States Gulf Coast]                 26.5B
# 21  [Central America, Yucatn Peninsula, South Flor...                  6.2B
# 22  [Greater Antilles, Bahamas, Eastern United Sta...                 5.37B
# 23  [The Caribbean, Venezuela, United States Gulf ...                 23.3B
# 24         [Windward Islands, Jamaica, Mexico, Texas]                 1.01B
# 25                [Bahamas, United States Gulf Coast]                  125B
# 26                   [Cuba, United States Gulf Coast]                   12B
# 27       [Greater Antilles, Central America, Florida]                 29.4B
# 28                   [The Caribbean, Central America]                 1.76B
# 29                              [Nicaragua, Honduras]                  720M
# 30  [Antilles, Venezuela, Colombia, United States ...                 15.1B
# 31  [Cape Verde, The Caribbean, British Virgin Isl...                 64.8B
# 32  [Lesser Antilles, Virgin Islands, Puerto Rico,...                 91.6B
# 33  [Central America, United States Gulf Coast (es...                 25.1B
#
#     death
# 0      90
# 1    4000
# 2      16
# 3    3103
# 4     179
# 5     184
# 6     408
# 7     682
# 8       5
# 9    1023
# 10     43
# 11    319
# 12    688
# 13    259
# 14     37
# 15     11
# 16   2068
# 17    269
# 18    318
# 19    107
# 20     65
# 21  19325
# 22     51
# 23    124
# 24     17
# 25   1836
# 26    125
# 27     87
# 28     45
# 29    133
# 30    603
# 31    138
# 32   3057
# 33     74

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Begin by looking at the damages list. The list contains strings representing the total cost in USD($) caused by 34 category 5 hurricanes (wind speeds ≥ 157 mph (252 km/h )) in the Atlantic region. For some of the hurricanes, damage data was not recorded ("Damages not recorded"), while the rest are written in the format "Prefix-B/M", where B stands for billions (1,000,000,000) and M stands for millions (1,000,000).
#
# - Transform the values of "xxxM" and "yyyB" into actual numbers (integer or float).
# - "Damages not recorded" should be changed to `np.nan`
#
# Hint: You need to use `.apply`

# %%
### Your code here
import numpy as np

def convert_damage(v):
  if v.endswith("M"):
    return float(v[:-1]) * 1000000
  if v.endswith("B"):
    return float(v[:-1]) * 1000000000
  if v == "Damages not recorded":
    return np.nan

hurricane_df['damage_number'] = hurricane_df['damage'].apply(convert_damage)
hurricane_df
# Out:
#                         name      month  year max_sustained_wind  \
# 0                     Cuba I    October  1924                165
# 1   San Felipe II Okeechobee  September  1928                160
# 2                    Bahamas  September  1932                160
# 3                    Cuba II   November  1932                175
# 4            CubaBrownsville     August  1933                160
# 5                    Tampico  September  1933                160
# 6                  Labor Day  September  1935                185
# 7                New England  September  1938                160
# 8                      Carol  September  1953                160
# 9                      Janet  September  1955                175
# 10                     Carla  September  1961                175
# 11                    Hattie    October  1961                160
# 12                    Beulah  September  1967                160
# 13                   Camille     August  1969                175
# 14                     Edith  September  1971                160
# 15                     Anita  September  1977                175
# 16                     David     August  1979                175
# 17                     Allen     August  1980                190
# 18                   Gilbert  September  1988                185
# 19                      Hugo  September  1989                160
# 20                    Andrew     August  1992                175
# 21                     Mitch    October  1998                180
# 22                    Isabel  September  2003                165
# 23                      Ivan  September  2004                165
# 24                     Emily       July  2005                160
# 25                   Katrina     August  2005                175
# 26                      Rita  September  2005                180
# 27                     Wilma    October  2005                185
# 28                      Dean     August  2007                175
# 29                     Felix  September  2007                175
# 30                   Matthew    October  2016                165
# 31                      Irma  September  2017                180
# 32                     Maria  September  2017                175
# 33                   Michael    October  2018                160
#
#                                        areas_affected                damage  \
# 0   [Central America, Mexico, Cuba, Florida, The B...  Damages not recorded
# 1   [Lesser Antilles, The Bahamas, United States E...                  100M
# 2           [The Bahamas, Northeastern United States]  Damages not recorded
# 3   [Lesser Antilles, Jamaica, Cayman Islands, Cub...                   40M
# 4     [The Bahamas, Cuba, Florida, Texas, Tamaulipas]                 27.9M
# 5                         [Jamaica, Yucatn Peninsula]                    5M
# 6   [The Bahamas, Florida, Georgia, The Carolinas,...  Damages not recorded
# 7   [Southeastern United States, Northeastern Unit...                  306M
# 8             [Bermuda, New England, Atlantic Canada]                    2M
# 9                  [Lesser Antilles, Central America]                 65.8M
# 10       [Texas, Louisiana, Midwestern United States]                  326M
# 11                                  [Central America]                 60.3M
# 12                     [The Caribbean, Mexico, Texas]                  208M
# 13                   [Cuba, United States Gulf Coast]                 1.42B
# 14  [The Caribbean, Central America, Mexico, Unite...                 25.4M
# 15                                           [Mexico]  Damages not recorded
# 16          [The Caribbean, United States East coast]                 1.54B
# 17  [The Caribbean, Yucatn Peninsula, Mexico, Sout...                 1.24B
# 18  [Jamaica, Venezuela, Central America, Hispanio...                  7.1B
# 19          [The Caribbean, United States East Coast]                   10B
# 20   [The Bahamas, Florida, United States Gulf Coast]                 26.5B
# 21  [Central America, Yucatn Peninsula, South Flor...                  6.2B
# 22  [Greater Antilles, Bahamas, Eastern United Sta...                 5.37B
# 23  [The Caribbean, Venezuela, United States Gulf ...                 23.3B
# 24         [Windward Islands, Jamaica, Mexico, Texas]                 1.01B
# 25                [Bahamas, United States Gulf Coast]                  125B
# 26                   [Cuba, United States Gulf Coast]                   12B
# 27       [Greater Antilles, Central America, Florida]                 29.4B
# 28                   [The Caribbean, Central America]                 1.76B
# 29                              [Nicaragua, Honduras]                  720M
# 30  [Antilles, Venezuela, Colombia, United States ...                 15.1B
# 31  [Cape Verde, The Caribbean, British Virgin Isl...                 64.8B
# 32  [Lesser Antilles, Virgin Islands, Puerto Rico,...                 91.6B
# 33  [Central America, United States Gulf Coast (es...                 25.1B
#
#     death  damage_number
# 0      90            NaN
# 1    4000   1.000000e+08
# 2      16            NaN
# 3    3103   4.000000e+07
# 4     179   2.790000e+07
# 5     184   5.000000e+06
# 6     408            NaN
# 7     682   3.060000e+08
# 8       5   2.000000e+06
# 9    1023   6.580000e+07
# 10     43   3.260000e+08
# 11    319   6.030000e+07
# 12    688   2.080000e+08
# 13    259   1.420000e+09
# 14     37   2.540000e+07
# 15     11            NaN
# 16   2068   1.540000e+09
# 17    269   1.240000e+09
# 18    318   7.100000e+09
# 19    107   1.000000e+10
# 20     65   2.650000e+10
# 21  19325   6.200000e+09
# 22     51   5.370000e+09
# 23    124   2.330000e+10
# 24     17   1.010000e+09
# 25   1836   1.250000e+11
# 26    125   1.200000e+10
# 27     87   2.940000e+10
# 28     45   1.760000e+09
# 29    133   7.200000e+08
# 30    603   1.510000e+10
# 31    138   6.480000e+10
# 32   3057   9.160000e+10
# 33     74   2.510000e+10

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Turn each row of record into dictionary.  Then use a large dictioanary to contain them.
#
# Your output should looks like:
#
# ```python
# {
#     "Cuba I": {"month": "October", ......},
#     "San Felipe II Okeechobee": {"month": "Septemper", ......},
#     "Bahamas": {"month": "Septemper", ......},
# }
# ```
#
# Hint: Read the documentation of `df.to_dict()`

# %%
### Your code here

hurricane_df.set_index("name").to_dict(orient="index")
# Out:
# {'Cuba I': {'month': 'October',
#   'year': 1924,
#   'max_sustained_wind': 165,
#   'areas_affected': ['Central America',
#    'Mexico',
#    'Cuba',
#    'Florida',
#    'The Bahamas'],
#   'damage': 'Damages not recorded',
#   'death': 90,
#   'damage_number': nan},
#  'San Felipe II Okeechobee': {'month': 'September',
#   'year': 1928,
#   'max_sustained_wind': 160,
#   'areas_affected': ['Lesser Antilles',
#    'The Bahamas',
#    'United States East Coast',
#    'Atlantic Canada'],
#   'damage': '100M',
#   'death': 4000,
#   'damage_number': 100000000.0},
#  'Bahamas': {'month': 'September',
#   'year': 1932,
#   'max_sustained_wind': 160,
#   'areas_affected': ['The Bahamas', 'Northeastern United States'],
#   'damage': 'Damages not recorded',
#   'death': 16,
#   'damage_number': nan},
#  'Cuba II': {'month': 'November',
#   'year': 1932,
#   'max_sustained_wind': 175,
#   'areas_affected': ['Lesser Antilles',
#    'Jamaica',
#    'Cayman Islands',
#    'Cuba',
#    'The Bahamas',
#    'Bermuda'],
#   'damage': '40M',
#   'death': 3103,
#   'damage_number': 40000000.0},
#  'CubaBrownsville': {'month': 'August',
#   'year': 1933,
#   'max_sustained_wind': 160,
#   'areas_affected': ['The Bahamas', 'Cuba', 'Florida', 'Texas', 'Tamaulipas'],
#   'damage': '27.9M',
#   'death': 179,
#   'damage_number': 27900000.0},
#  'Tampico': {'month': 'September',
#   'year': 1933,
#   'max_sustained_wind': 160,
#   'areas_affected': ['Jamaica', 'Yucatn Peninsula'],
#   'damage': '5M',
#   'death': 184,
#   'damage_number': 5000000.0},
#  'Labor Day': {'month': 'September',
#   'year': 1935,
#   'max_sustained_wind': 185,
#   'areas_affected': ['The Bahamas',
#    'Florida',
#    'Georgia',
#    'The Carolinas',
#    'Virginia'],
#   'damage': 'Damages not recorded',
#   'death': 408,
#   'damage_number': nan},
#  'New England': {'month': 'September',
#   'year': 1938,
#   'max_sustained_wind': 160,
#   'areas_affected': ['Southeastern United States',
#    'Northeastern United States',
#    'Southwestern Quebec'],
#   'damage': '306M',
#   'death': 682,
#   'damage_number': 306000000.0},
#  'Carol': {'month': 'September',
#   'year': 1953,
#   'max_sustained_wind': 160,
#   'areas_affected': ['Bermuda', 'New England', 'Atlantic Canada'],
#   'damage': '2M',
#   'death': 5,
#   'damage_number': 2000000.0},
#  'Janet': {'month': 'September',
#   'year': 1955,
#   'max_sustained_wind': 175,
#   'areas_affected': ['Lesser Antilles', 'Central America'],
#   'damage': '65.8M',
#   'death': 1023,
#   'damage_number': 65800000.0},
#  'Carla': {'month': 'September',
#   'year': 1961,
#   'max_sustained_wind': 175,
#   'areas_affected': ['Texas', 'Louisiana', 'Midwestern United States'],
#   'damage': '326M',
#   'death': 43,
#   'damage_number': 326000000.0},
#  'Hattie': {'month': 'October',
#   'year': 1961,
#   'max_sustained_wind': 160,
#   'areas_affected': ['Central America'],
#   'damage': '60.3M',
#   'death': 319,
#   'damage_number': 60300000.0},
#  'Beulah': {'month': 'September',
#   'year': 1967,
#   'max_sustained_wind': 160,
#   'areas_affected': ['The Caribbean', 'Mexico', 'Texas'],
#   'damage': '208M',
#   'death': 688,
#   'damage_number': 208000000.0},
#  'Camille': {'month': 'August',
#   'year': 1969,
#   'max_sustained_wind': 175,
#   'areas_affected': ['Cuba', 'United States Gulf Coast'],
#   'damage': '1.42B',
#   'death': 259,
#   'damage_number': 1420000000.0},
#  'Edith': {'month': 'September',
#   'year': 1971,
#   'max_sustained_wind': 160,
#   'areas_affected': ['The Caribbean',
#    'Central America',
#    'Mexico',
#    'United States Gulf Coast'],
#   'damage': '25.4M',
#   'death': 37,
#   'damage_number': 25400000.0},
#  'Anita': {'month': 'September',
#   'year': 1977,
#   'max_sustained_wind': 175,
#   'areas_affected': ['Mexico'],
#   'damage': 'Damages not recorded',
#   'death': 11,
#   'damage_number': nan},
#  'David': {'month': 'August',
#   'year': 1979,
#   'max_sustained_wind': 175,
#   'areas_affected': ['The Caribbean', 'United States East coast'],
#   'damage': '1.54B',
#   'death': 2068,
#   'damage_number': 1540000000.0},
#  'Allen': {'month': 'August',
#   'year': 1980,
#   'max_sustained_wind': 190,
#   'areas_affected': ['The Caribbean',
#    'Yucatn Peninsula',
#    'Mexico',
#    'South Texas'],
#   'damage': '1.24B',
#   'death': 269,
#   'damage_number': 1240000000.0},
#  'Gilbert': {'month': 'September',
#   'year': 1988,
#   'max_sustained_wind': 185,
#   'areas_affected': ['Jamaica',
#    'Venezuela',
#    'Central America',
#    'Hispaniola',
#    'Mexico'],
#   'damage': '7.1B',
#   'death': 318,
#   'damage_number': 7100000000.0},
#  'Hugo': {'month': 'September',
#   'year': 1989,
#   'max_sustained_wind': 160,
#   'areas_affected': ['The Caribbean', 'United States East Coast'],
#   'damage': '10B',
#   'death': 107,
#   'damage_number': 10000000000.0},
#  'Andrew': {'month': 'August',
#   'year': 1992,
#   'max_sustained_wind': 175,
#   'areas_affected': ['The Bahamas', 'Florida', 'United States Gulf Coast'],
#   'damage': '26.5B',
#   'death': 65,
#   'damage_number': 26500000000.0},
#  'Mitch': {'month': 'October',
#   'year': 1998,
#   'max_sustained_wind': 180,
#   'areas_affected': ['Central America', 'Yucatn Peninsula', 'South Florida'],
#   'damage': '6.2B',
#   'death': 19325,
#   'damage_number': 6200000000.0},
#  'Isabel': {'month': 'September',
#   'year': 2003,
#   'max_sustained_wind': 165,
#   'areas_affected': ['Greater Antilles',
#    'Bahamas',
#    'Eastern United States',
#    'Ontario'],
#   'damage': '5.37B',
#   'death': 51,
#   'damage_number': 5370000000.0},
#  'Ivan': {'month': 'September',
#   'year': 2004,
#   'max_sustained_wind': 165,
#   'areas_affected': ['The Caribbean', 'Venezuela', 'United States Gulf Coast'],
#   'damage': '23.3B',
#   'death': 124,
#   'damage_number': 23300000000.0},
#  'Emily': {'month': 'July',
#   'year': 2005,
#   'max_sustained_wind': 160,
#   'areas_affected': ['Windward Islands', 'Jamaica', 'Mexico', 'Texas'],
#   'damage': '1.01B',
#   'death': 17,
#   'damage_number': 1010000000.0},
#  'Katrina': {'month': 'August',
#   'year': 2005,
#   'max_sustained_wind': 175,
#   'areas_affected': ['Bahamas', 'United States Gulf Coast'],
#   'damage': '125B',
#   'death': 1836,
#   'damage_number': 125000000000.0},
#  'Rita': {'month': 'September',
#   'year': 2005,
#   'max_sustained_wind': 180,
#   'areas_affected': ['Cuba', 'United States Gulf Coast'],
#   'damage': '12B',
#   'death': 125,
#   'damage_number': 12000000000.0},
#  'Wilma': {'month': 'October',
#   'year': 2005,
#   'max_sustained_wind': 185,
#   'areas_affected': ['Greater Antilles', 'Central America', 'Florida'],
#   'damage': '29.4B',
#   'death': 87,
#   'damage_number': 29400000000.0},
#  'Dean': {'month': 'August',
#   'year': 2007,
#   'max_sustained_wind': 175,
#   'areas_affected': ['The Caribbean', 'Central America'],
#   'damage': '1.76B',
#   'death': 45,
#   'damage_number': 1760000000.0},
#  'Felix': {'month': 'September',
#   'year': 2007,
#   'max_sustained_wind': 175,
#   'areas_affected': ['Nicaragua', 'Honduras'],
#   'damage': '720M',
#   'death': 133,
#   'damage_number': 720000000.0},
#  'Matthew': {'month': 'October',
#   'year': 2016,
#   'max_sustained_wind': 165,
#   'areas_affected': ['Antilles',
#    'Venezuela',
#    'Colombia',
#    'United States East Coast',
#    'Atlantic Canada'],
#   'damage': '15.1B',
#   'death': 603,
#   'damage_number': 15100000000.0},
#  'Irma': {'month': 'September',
#   'year': 2017,
#   'max_sustained_wind': 180,
#   'areas_affected': ['Cape Verde',
#    'The Caribbean',
#    'British Virgin Islands',
#    'U.S. Virgin Islands',
#    'Cuba',
#    'Florida'],
#   'damage': '64.8B',
#   'death': 138,
#   'damage_number': 64800000000.0},
#  'Maria': {'month': 'September',
#   'year': 2017,
#   'max_sustained_wind': 175,
#   'areas_affected': ['Lesser Antilles',
#    'Virgin Islands',
#    'Puerto Rico',
#    'Dominican Republic',
#    'Turks and Caicos Islands'],
#   'damage': '91.6B',
#   'death': 3057,
#   'damage_number': 91600000000.0},
#  'Michael': {'month': 'October',
#   'year': 2018,
#   'max_sustained_wind': 160,
#   'areas_affected': ['Central America',
#    'United States Gulf Coast (especially Florida Panhandle)'],
#   'damage': '25.1B',
#   'death': 74,
#   'damage_number': 25100000000.0}}

# %% [markdown]
# #### Exercise 3

# %% [markdown]
# In addition to organizing the hurricanes in a dictionary with names as the key, you want to be able to organize the hurricanes by year.
#
# How many hurricans happened each year?  Create a bar plot to visualize the change of hurricanes over years.

# %%
### Your code here
import matplotlib.pyplot as plt

counts = hurricane_df['year'].value_counts()
plt.bar(counts.index, counts.values)
# Out:
# <BarContainer object of 26 artists>

# %%
hurricane_df['year'].hist(bins=(hurricane_df['year'].max() - hurricane_df['year'].min() + 1))
# Out:
# <Axes: >

# %% [markdown]
# #### Exercise 4

# %% [markdown]
# You believe that knowing how often each of the areas of the Atlantic are affected by these strong hurricanes is important for making preparations for future hurricanes.
#
# Counts how often each area is listed as an affected area of a hurricane.
#
# For example `{"Cayman Islands": 10, "Jamaica": 20, ...}`
#
# *Hint: Think out of `pandas`!*

# %%
np.concatenate(hurricane_df['areas_affected'].apply(np.array))
# Out:
# array(['Central America', 'Mexico', 'Cuba', 'Florida', 'The Bahamas',
#        'Lesser Antilles', 'The Bahamas', 'United States East Coast',
#        'Atlantic Canada', 'The Bahamas', 'Northeastern United States',
#        'Lesser Antilles', 'Jamaica', 'Cayman Islands', 'Cuba',
#        'The Bahamas', 'Bermuda', 'The Bahamas', 'Cuba', 'Florida',
#        'Texas', 'Tamaulipas', 'Jamaica', 'Yucatn Peninsula',
#        'The Bahamas', 'Florida', 'Georgia', 'The Carolinas', 'Virginia',
#        'Southeastern United States', 'Northeastern United States',
#        'Southwestern Quebec', 'Bermuda', 'New England', 'Atlantic Canada',
#        'Lesser Antilles', 'Central America', 'Texas', 'Louisiana',
#        'Midwestern United States', 'Central America', 'The Caribbean',
#        'Mexico', 'Texas', 'Cuba', 'United States Gulf Coast',
#        'The Caribbean', 'Central America', 'Mexico',
#        'United States Gulf Coast', 'Mexico', 'The Caribbean',
#        'United States East coast', 'The Caribbean', 'Yucatn Peninsula',
#        'Mexico', 'South Texas', 'Jamaica', 'Venezuela', 'Central America',
#        'Hispaniola', 'Mexico', 'The Caribbean',
#        'United States East Coast', 'The Bahamas', 'Florida',
#        'United States Gulf Coast', 'Central America', 'Yucatn Peninsula',
#        'South Florida', 'Greater Antilles', 'Bahamas',
#        'Eastern United States', 'Ontario', 'The Caribbean', 'Venezuela',
#        'United States Gulf Coast', 'Windward Islands', 'Jamaica',
#        'Mexico', 'Texas', 'Bahamas', 'United States Gulf Coast', 'Cuba',
#        'United States Gulf Coast', 'Greater Antilles', 'Central America',
#        'Florida', 'The Caribbean', 'Central America', 'Nicaragua',
#        'Honduras', 'Antilles', 'Venezuela', 'Colombia',
#        'United States East Coast', 'Atlantic Canada', 'Cape Verde',
#        'The Caribbean', 'British Virgin Islands', 'U.S. Virgin Islands',
#        'Cuba', 'Florida', 'Lesser Antilles', 'Virgin Islands',
#        'Puerto Rico', 'Dominican Republic', 'Turks and Caicos Islands',
#        'Central America',
#        'United States Gulf Coast (especially Florida Panhandle)'],
#       dtype='<U55')

# %%
### Your code here

# d = {}

# for some_areas in hurricane_df['areas_affected']:

#   for area in some_areas:

#     if area in d:
#       d[area] += 1
#     else:
#       d[area] = 1

# d

from collections import Counter

Counter(hurricane_df['areas_affected'].sum())
# Out:
# Counter({'Central America': 9,
#          'Mexico': 7,
#          'Cuba': 6,
#          'Florida': 6,
#          'The Bahamas': 7,
#          'Lesser Antilles': 4,
#          'United States East Coast': 3,
#          'Atlantic Canada': 3,
#          'Northeastern United States': 2,
#          'Jamaica': 4,
#          'Cayman Islands': 1,
#          'Bermuda': 2,
#          'Texas': 4,
#          'Tamaulipas': 1,
#          'Yucatn Peninsula': 3,
#          'Georgia': 1,
#          'The Carolinas': 1,
#          'Virginia': 1,
#          'Southeastern United States': 1,
#          'Southwestern Quebec': 1,
#          'New England': 1,
#          'Louisiana': 1,
#          'Midwestern United States': 1,
#          'The Caribbean': 8,
#          'United States Gulf Coast': 6,
#          'United States East coast': 1,
#          'South Texas': 1,
#          'Venezuela': 3,
#          'Hispaniola': 1,
#          'South Florida': 1,
#          'Greater Antilles': 2,
#          'Bahamas': 2,
#          'Eastern United States': 1,
#          'Ontario': 1,
#          'Windward Islands': 1,
#          'Nicaragua': 1,
#          'Honduras': 1,
#          'Antilles': 1,
#          'Colombia': 1,
#          'Cape Verde': 1,
#          'British Virgin Islands': 1,
#          'U.S. Virgin Islands': 1,
#          'Virgin Islands': 1,
#          'Puerto Rico': 1,
#          'Dominican Republic': 1,
#          'Turks and Caicos Islands': 1,
#          'United States Gulf Coast (especially Florida Panhandle)': 1})

# %% [markdown]
# #### Exercise 5

# %% [markdown]
# Find the hurricane that caused the greatest number of deaths, and how many deaths it caused.

# %%
### Your code here

hurricane_df[hurricane_df['death'] == hurricane_df['death'].max()]
# Out:
#      name    month  year max_sustained_wind  \
# 21  Mitch  October  1998                180
#
#                                        areas_affected damage  death  \
# 21  [Central America, Yucatn Peninsula, South Flor...   6.2B  19325
#
#     damage_number
# 21   6.200000e+09

# %% [markdown]
# #### Exercise 6

# %% [markdown]
# Just as hurricanes are rated by their windspeed, you want to try rating hurricanes based on other metrics.
#
# Write a function that rates hurricanes on a mortality scale according to the following ratings, where the key is the rating and the value is the upper bound of deaths for that rating.
#
# ```
# mortality_scale = {
#     0: 0,
#     1: 100,
#     2: 500,
#     3: 1000,
#     4: 10000
# }
# ```
#
# For example, a hurricane with a 1 mortality rating would have resulted in greater than 0 but less than or equal to 100 deaths. A hurricane with a 5 mortality rating would have resulted in greater than 10000 deaths.
#
# 1. Create a series that stores the mortality scale.
# 2. Create a barplot where the x-axis are the mortality numbers, and the y-axis is the number of hurricans fall into the group.

# %%
### Your code here

pd.DataFrame({
    "death": hurricane_df['death'],
    "group": pd.cut(hurricane_df['death'], [float("-inf"), 0, 100, 500, 1000, 10000, float("inf")])
})
# Out:
#     death              group
# 0      90       (0.0, 100.0]
# 1    4000  (1000.0, 10000.0]
# 2      16       (0.0, 100.0]
# 3    3103  (1000.0, 10000.0]
# 4     179     (100.0, 500.0]
# 5     184     (100.0, 500.0]
# 6     408     (100.0, 500.0]
# 7     682    (500.0, 1000.0]
# 8       5       (0.0, 100.0]
# 9    1023  (1000.0, 10000.0]
# 10     43       (0.0, 100.0]
# 11    319     (100.0, 500.0]
# 12    688    (500.0, 1000.0]
# 13    259     (100.0, 500.0]
# 14     37       (0.0, 100.0]
# 15     11       (0.0, 100.0]
# 16   2068  (1000.0, 10000.0]
# 17    269     (100.0, 500.0]
# 18    318     (100.0, 500.0]
# 19    107     (100.0, 500.0]
# 20     65       (0.0, 100.0]
# 21  19325     (10000.0, inf]
# 22     51       (0.0, 100.0]
# 23    124     (100.0, 500.0]
# 24     17       (0.0, 100.0]
# 25   1836  (1000.0, 10000.0]
# 26    125     (100.0, 500.0]
# 27     87       (0.0, 100.0]
# 28     45       (0.0, 100.0]
# 29    133     (100.0, 500.0]
# 30    603    (500.0, 1000.0]
# 31    138     (100.0, 500.0]
# 32   3057  (1000.0, 10000.0]
# 33     74       (0.0, 100.0]

# %%
def motality_scale(v):
  if v <= 0:
    return 0
  if v <= 100:
    return 1
  if v <= 500:
    return 2
  if v <= 1000:
    return 3
  if v <= 10000:
    return 4

  return 5


hurricane_df['death'].apply(motality_scale).value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='death'>

# %%
pd.cut(hurricane_df['death'], [float("-inf"), 0, 100, 500, 1000, 10000, float("inf")]).value_counts().sort_index().reset_index(drop=True).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# #### Exercise 7

# %% [markdown]
# Besides mortality, you want to rate hurricanes according to how much damage they cause.
#
# ```
# damage_scale = {
#     0: 0,
#     1: 100000000,
#     2: 1000000000,
#     3: 10000000000,
#     4: 50000000000
# }
# ```
#
# For example, a hurricane with a 1 damage rating would have resulted in damages greater than 0 USD but less than or equal to 100000000 USD. A hurricane with a 5 damage rating would have resulted in damages greater than 50000000000 USD (talk about a lot of money).
#
# 1. Create a series that stores the damage scale.
# 2. Create a barplot where the x-axis are the death scale numbers, and the y-axis is the number of hurricans fall into the group.

# %%
### Your code here

def damage_scale(v):

  if np.isnan(v):
    return np.nan

  if v <= 0:
    return 0
  if v <= 100000000:
    return 1
  if v <= 1000000000:
    return 2
  if v <= 10000000000:
    return 3
  if v <= 50000000000:
    return 4

  return 5


hurricane_df['damage_number'].apply(damage_scale).value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='damage_number'>

# %% [markdown]
# ### Exercise 8

# %% [markdown]
# We are interested in the relationship between
# - Mortality scale and
# - Damage scale
#
# Create a scattered plot to show the relationship between the two.
#
# Are they highly correlated or uncorrelated?

# %%
### Your code here
x = hurricane_df['damage_number'].apply(damage_scale)
y = hurricane_df['death'].apply(motality_scale)

# %%
plt.scatter(x + 0.2 * (np.random.random(len(x)) - 0.5) , y + 0.2 * (np.random.random(len(y)) - 0.5))

# %%
import seaborn as sns

sns.stripplot(
    x=x,
    y=y
)
# Out:
# <Axes: xlabel='damage_number', ylabel='death'>
