# %%
import requests

# %%
response = requests.get("https://www.hko.gov.hk/wxinfo/json/one_json.xml")

# %%
import json

# %%
json.loads(response.text)['hko']['Temperature']
# Out:
# '27.3'
