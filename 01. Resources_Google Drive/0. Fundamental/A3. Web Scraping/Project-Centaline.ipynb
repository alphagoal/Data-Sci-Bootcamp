# %% [markdown]
# ## Web Scraping Exercise - Centaline

# %% [markdown]
# Try to extract first 2 page of the search result and store the information into lists
#
# 1. Find the API end point you want to use by checking network request
# 2. Send the Post request with body in json format
# 3. Return the response in json format and locate the key which stores the information

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install urllib3==1.25.11

# %%
import requests
