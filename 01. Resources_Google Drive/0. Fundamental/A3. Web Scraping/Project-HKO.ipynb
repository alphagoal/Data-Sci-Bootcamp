# %% [markdown]
# ## Web Scraping Exercise: HKO

# %% [markdown]
# Try to extract the current temperature on the front page:
#
#
# 1. Find the API end point you want to use by checking network request
# 2. Send the Get request
# 3. Return the response in json format and locate the key which stores the information

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import requests
